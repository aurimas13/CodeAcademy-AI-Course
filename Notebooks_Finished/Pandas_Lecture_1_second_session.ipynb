# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# ## Create A `Series` Object

# %%
# Create series String
ice_cream = ['Chocolate', 'Vanilla', 'Strawberry', 'Whisky']
             
pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1       Vanilla
# 2    Strawberry
# 3        Whisky
# dtype: object

# %%
# Create series Ints
lottery = [4, 8, 15, 16, 23, 42]
pd.Series(lottery)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
# Create series Boolean
registrations = [True, False, False, False, True]
pd.Series(registrations)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
# Create Series from dict
webster = {'Zebra': 'An animal',
           'Banana': 'A delicious fruit',
           'Blue': 'A color'}
pd.Series(webster)
# Out:
# Zebra             An animal
# Banana    A delicious fruit
# Blue                A color
# dtype: object

# %% [markdown]
# ## Create A `DataFrame` Object

# %% [markdown]
# ### Dict

# %%
# First method to create DataFrame from [{},{},{}]
sales = [{'account': 'LLC', 'Jan': 200, 'Feb': 150, 'Mar': 180},
          {'account': 'Co', 'Jan': 150, 'Feb': 170, 'Mar': 190},
          {'account': 'Blue Inc', 'Jan': 160, 'Feb': 195, 'Mar': 250}]
df = pd.DataFrame(sales)
df
# Out:
#     account  Jan  Feb  Mar
# 0       LLC  200  150  180
# 1        Co  150  170  190
# 2  Blue Inc  160  195  250

# %%
# Second method to create DataFrame from [{-:[],-:[],-:[]}, from_dict
sales = {'account': ['LLC', 'Co', 'Blue Inc'],
         'Jan': [200, 150, 160],
         'Feb': [150, 170, 195],
         'Mar': [180, 190, 250]}
df = pd.DataFrame(series)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 6>()
#       1 # Second method to create DataFrame from [{-:[],-:[],-:[]}, from_dict
#       2 sales = {'account': ['LLC', 'Co', 'Blue Inc'],
#       3          'Jan': [200, 150, 160],
#       4          'Feb': [150, 170, 195],
#       5          'Mar': [180, 190, 250]}
# ----> 6 df = pd.DataFrame(series)
#       7 df
#
# NameError: name 'series' is not defined

# %% [markdown]
# ### List

# %%
# Third method to create DataFrame from sales=[(),(),()] labels=['','','',''] from_records(sales, columns=labels)
sales = [('LLC', 200, 150, 180),
         ('Co', 150, 170, 190),
         ('Blue Inc', 160, 195, 250)]
labels = ['account', 'Jan', 'Feb', 'Mar']
df = pd.DataFrame.from_records(sales, columns=labels)
df
# Out:
#     account  Jan  Feb  Mar
# 0       LLC  200  150  180
# 1        Co  150  170  190
# 2  Blue Inc  160  195  250

# %% [markdown]
# ### 4th method deprecated - Don't USE IT

# %%
# Fourth method to create DataFrame is DEPRECATED. Don't use it. 
# sales = ['',['','','']], ('',['','',''], etcX2 from_items(sales)
sales = [('account', ['Jones LLC', 'Alpha Co', 'Blue Inc']),
         ('Jan', [150, 200, 50]),
         ('Feb', [200, 210, 90]),
         ('Mar', [140, 215, 95])]
df = pd.DataFrame.from_items(sales)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 7>()
#       1 # Fourth method to create DataFrame is DEPRECATED. Don't use it.
#       2 # sales = ['',['','','']], ('',['','',''], etcX2 from_items(sales)
#       3 sales = [('account', ['Jones LLC', 'Alpha Co', 'Blue Inc']),
#       4          ('Jan', [150, 200, 50]),
#       5          ('Feb', [200, 210, 90]),
#       6          ('Mar', [140, 215, 95])]
# ----> 7 df = pd.DataFrame.from_items(sales)
#
# AttributeError: type object 'DataFrame' has no attribute 'from_items'

# %% [markdown]
# # Data Input Formats

# %%
exchange_rates = pd.read_csv("Data/dollar_euro.txt", sep="\t")
exchange_rates
# Out:
#     Year   Average  Min USD/EUR  Max USD/EUR  Working days
# 0   2016  0.901696     0.864379     0.959785           247
# 1   2015  0.901896     0.830358     0.947688           256
# 2   2014  0.753941     0.716692     0.823655           255
# 3   2013  0.753234     0.723903     0.783208           255
# 4   2012  0.778848     0.743273     0.827198           256
# 5   2011  0.719219     0.671953     0.775855           257
# 6   2010  0.755883     0.686672     0.837381           258
# 7   2009  0.718968     0.661376     0.796495           256
# 8   2008  0.683499     0.625391     0.802568           256
# 9   2007  0.730754     0.672314     0.775615           255
# 10  2006  0.797153     0.750131     0.845594           255
# 11  2005  0.805097     0.740357     0.857118           257
# 12  2004  0.804828     0.733514     0.847314           259
# 13  2003  0.885766     0.791766     0.963670           255
# 14  2002  1.060945     0.953562     1.165773           255
# 15  2001  1.117587     1.047669     1.192748           255
# 16  2000  1.085899     0.962649     1.211827           255
# 17  1999  0.939475     0.848176     0.998502           261

# %%
column_names =['Country'] + list(range(2002,2013))
male_pop = pd.read_csv("Data/countries_male_population.csv",
            header=None,
            index_col=0,
            names=column_names)
female_pop = pd.read_csv("Data/countries_female_population.csv",
            header=None,
            index_col=0,
            names=column_names)
population = male_pop + female_pop
population.to_csv("Data/countries_total_population.csv")
population.head()
# Out:
#                       2002      2003      2004      2005      2006      2007  \
# Country
# Australia       19640979.0  19872646  20091504  20339759  20605488  21015042
# Austria          8139310.0   8067289   8140122   8206524   8265925   8298923
# Belgium         10309725.0  10355844  10396421  10445852  10511382  10584534
# Canada                 NaN  31361611  31372587  31989454  32299496  32649482
# Czech Republic  10269726.0  10203269  10211455  10220577  10251079  10287189
#
#                     2008      2009      2010      2011      2012
# Country
# Australia       21431781  21874920  22342398  22620554  22683573
# Austria          8331930   8355260   8375290   8404252   8443018
# Belgium         10666866  10753080  10839905  10366843  11035958
# Canada          32927372  33327337  33334414  33927935  34492645
# Czech Republic  10381130  10467542  10506813  10532770  10505445

# %%
titanic = pd.read_csv("Data/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.to_excel("Data/titanic.xlsx", sheet_name="passengers", index=False)

# %%
titanic_excel = pd.read_excel("Data/titanic.xlsx", sheet_name="passengers")
titanic_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Working with JSON

# %%
# when JSON is a simple dict:
a_dict = {
    'school': 'ABC primary school',
    'location': 'Vilnius',
    'ranking': 1,
}
pd.json_normalize(a_dict)
# Out:
#                school location  ranking
# 0  ABC primary school  Vilnius        1

# %%
# when a list of dicts
json_list = [
    { 'class': 'Year 1', 'student number': 20, 'name': 'Yellow' },
    { 'class': 'Year 2', 'student number': 25, 'name': 'Blue' },
]
pd.json_normalize(json_list)
# Out:
#     class  student number    name
# 0  Year 1              20  Yellow
# 1  Year 2              25    Blue

# %%
# when JSON is a nested list
json_obj = {
    'school': 'ABC primary school',
    'location': 'Lithuania',
    'ranking': 1,
    'info': {
        'president': 'Edgaras',
        'contacts': {
            'email': {
                'admission': 'admission@abc.com',
                'general': 'info@abc.com'
            },
            'tel': '123456789',
        }
    },
    'students': [
        { 'name': 'Agne' },
        { 'name': 'Viaceslav' },
        { 'name': 'Antanas'}
    ],
}
pd.json_normalize(json_obj)
# Out:
#                school   location  ranking  \
# 0  ABC primary school  Lithuania        1
#
#                                             students info.president  \
# 0  [{'name': 'Agne'}, {'name': 'Viaceslav'}, {'na...        Edgaras
#
#   info.contacts.email.admission info.contacts.email.general info.contacts.tel
# 0             admission@abc.com                info@abc.com         123456789

# %%
pd.json_normalize(json_obj, record_path=['students'])
# Out:
#         name
# 0       Agne
# 1  Viaceslav
# 2    Antanas

# %%
# when errors like nan
data = [
    {
        'class': 'Year 1',
        'student count': 20,
        'room': 'Yellow',
        'info': {
            'teachers': {
                'math': 'Deividas',
                'physics': 'Vidmantas',
            }
        },
        'students': [
            { 'name': 'Agne', 'sex': 'F' },
            { 'name': 'Viaceslav', 'sex': 'M'},
        ]
    },
    {
        'class': 'Year 2',
        'student count': 25,
        'room': 'Blue',
        'info': {
            'teachers': {
                # no math teacher
                'physics': 'Erikas',
            }
        },
        'students': [
            { 'name': 'Antanas', 'sex': 'M' },
            { 'name': 'Ausra', 'sex': 'F'},
        ]
    },
]

# %%
pd.json_normalize(
    data,
    record_path=['students'],
    meta=['class', 'room', ['info', 'teachers', 'math']],
    errors='ignore'
)
# Out:
#         name sex   class    room info.teachers.math
# 0       Agne   F  Year 1  Yellow           Deividas
# 1  Viaceslav   M  Year 1  Yellow           Deividas
# 2    Antanas   M  Year 2    Blue                NaN
# 3      Ausra   F  Year 2    Blue                NaN

# %% [markdown]
# ## <i>Exploring the NBA data</i>

# %%
nba = pd.read_csv("Data/nba.csv")
nba.columns
nba.count
nba.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# # <b> More useful for data analysis is manipulating A `Dataframe` Object </b>

# %% [markdown]
# ## Some shared methods and attributes with `Series`

# %%
#front
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#end
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
#idx
nba.index
# Out:
# RangeIndex(start=0, stop=457, step=1)

# %%
#values
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Raul Neto', 'Utah Jazz', 25.0, ..., 179.0, nan, 900000.0],
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0]],
#       dtype=object)

# %%
#columns
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
# Take one column .Team
nba.Team
# Out:
# 0      Boston Celtics
# 1      Boston Celtics
# 2      Boston Celtics
# 3      Boston Celtics
# 4      Boston Celtics
#             ...
# 452         Utah Jazz
# 453         Utah Jazz
# 454         Utah Jazz
# 455         Utah Jazz
# 456         Utah Jazz
# Name: Team, Length: 457, dtype: object

# %%
# Take one column 'Team'
nba['Team']
# Out:
# 0      Boston Celtics
# 1      Boston Celtics
# 2      Boston Celtics
# 3      Boston Celtics
# 4      Boston Celtics
#             ...
# 452         Utah Jazz
# 453         Utah Jazz
# 454         Utah Jazz
# 455         Utah Jazz
# 456         Utah Jazz
# Name: Team, Length: 457, dtype: object

# %%
nba.dtypes.value_counts()
# Out:
# object     5
# float64    4
# dtype: int64

# %% [markdown]
# ## Same `Series` attributes

# %%
nba_series = pd.read_csv("Data/nba.csv", usecols = ["Name"], squeeze = True)
nba_series.head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
nba_series.values
# nba_series.index
# nba_series.dtype
nba_series.value_counts()
# nba_series.value_counts().sum()
# nba_series.count()
# nba_series.is_unique
# nba_series.ndim
# Out:
# Avery Bradley       1
# Kyle Korver         1
# Al Horford          1
# Kirk Hinrich        1
# Tim Hardaway Jr.    1
#                    ..
# Eric Moreland       1
# Ben McLemore        1
# Kosta Koufos        1
# Rudy Gay            1
# Jeff Withey         1
# Name: Name, Length: 457, dtype: int64

# %%
s = pd.Series([1.0, 2.0, 2.0, 243.0])
s.value_counts().sum()
s.count()
# Out:
# 4

# %% [markdown]
# ## Select one column from A `DataFrame` Object

# %%
# nba_one['Team'] vs nba_one[["Team"]]
nba_one = pd.read_csv("Data/nba.csv")
nba['Team'].head()
nba[['Team']].head()
# Out:
#              Team
# 0  Boston Celtics
# 1  Boston Celtics
# 2  Boston Celtics
# 3  Boston Celtics
# 4  Boston Celtics

# %% [markdown]
# ## Select two or more columns from A `DataFrame` Object

# %%
# Team, Name | Number, College | 'Salary', 'Team', 'Name'
nba = pd.read_csv("Data/nba.csv")
nba[['Team', 'Name']].head(3)
nba[['Team', 'Name', 'Salary']].tail(7)
# Out:
#           Team           Name     Salary
# 450  Utah Jazz     Joe Ingles  2050000.0
# 451  Utah Jazz  Chris Johnson   981348.0
# 452  Utah Jazz     Trey Lyles  2239800.0
# 453  Utah Jazz   Shelvin Mack  2433333.0
# 454  Utah Jazz      Raul Neto   900000.0
# 455  Utah Jazz   Tibor Pleiss  2900000.0
# 456  Utah Jazz    Jeff Withey   947276.0

# %% [markdown]
# ## Add a new column to A `DataFrame` Object

# %%
nba['Sport'] = 'Basketball'
nba.head(3)
nba_create_column = pd.read_csv('Data/nba.csv')
nba_create_column.head()
nba_create_column.insert(3, column='Sport', value='Krepsinis')
nba_create_column.head()
# Out:
#             Name            Team  Number      Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Krepsinis       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Krepsinis       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Krepsinis       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Krepsinis       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Krepsinis       PF  29.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %% [markdown]
# ## <b> Time to look at the exercises </b>

# %% [markdown]
# # Indexing and Filtering

# %%
nba = pd.read_csv("Data/nba.csv")

# %% [markdown]
# ### Selecting

# %%
#Pasirenki viena stulpeli per ''
nba['Team']
# Out:
# 0      Boston Celtics
# 1      Boston Celtics
# 2      Boston Celtics
# 3      Boston Celtics
# 4      Boston Celtics
#             ...
# 452         Utah Jazz
# 453         Utah Jazz
# 454         Utah Jazz
# 455         Utah Jazz
# 456         Utah Jazz
# Name: Team, Length: 457, dtype: object

# %%
#Pasirenki viena stulpeli per .stulpelis
nba.Team
# Out:
# 0      Boston Celtics
# 1      Boston Celtics
# 2      Boston Celtics
# 3      Boston Celtics
# 4      Boston Celtics
#             ...
# 452         Utah Jazz
# 453         Utah Jazz
# 454         Utah Jazz
# 455         Utah Jazz
# 456         Utah Jazz
# Name: Team, Length: 457, dtype: object

# %%
#Pasirenki dvi eilutes Name ir Teams per [[]]
nba[['Team', 'Name']].head()
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland
# 3  Boston Celtics    R.J. Hunter
# 4  Boston Celtics  Jonas Jerebko

# %% [markdown]
# ### The `.value_counts()` method

# %%
#3 budai
nba.value_counts()
nba.value_counts(dropna=False)
# Out:
# Name                Team                    Number  Position  Age   Height  Weight  College     Salary
# Aaron Brooks        Chicago Bulls           0.0     PG        31.0  6-0     161.0   Oregon      2250000.0     1
# Miles Plumlee       Milwaukee Bucks         18.0    C         27.0  6-11    249.0   Duke        2109294.0     1
# Mike Muscala        Atlanta Hawks           31.0    PF        24.0  6-11    240.0   Bucknell    947276.0      1
# Mike Miller         Denver Nuggets          3.0     SG        36.0  6-8     218.0   Florida     947276.0      1
# Mike Dunleavy       Chicago Bulls           34.0    SG        35.0  6-9     230.0   Duke        4500000.0     1
#                                                                                                              ..
# Gorgui Dieng        Minnesota Timberwolves  5.0     C         26.0  6-11    241.0   Louisville  1474440.0     1
# Gordon Hayward      Utah Jazz               20.0    SF        26.0  6-8     226.0   Butler      15409570.0    1
# Goran Dragic        Miami Heat              7.0     PG        30.0  6-3     190.0   NaN         14783000.0    1
# Glenn Robinson III  Indiana Pacers          40.0    SG        22.0  6-7     222.0   Michigan    1100000.0     1
# Zaza Pachulia       Dallas Mavericks        27.0    C         32.0  6-11    275.0   NaN         5200000.0     1
# Length: 457, dtype: int64

# %% [markdown]
# ## The `.astype()` method &  `.unique()` and `.nunique()` methods

# %%
#2/3 budai
nba['Salary'] = nba['Salary'].fillna(0).astype('int')
nba['Age'] = nba['Age'].astype('int')

nba.head(10)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF   29    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF   21    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C   25    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG   22    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG   22    6-4   220.0
#
#              College    Salary
# 0              Texas   7730337
# 1          Marquette   6796117
# 2  Boston University         0
# 3      Georgia State   1148640
# 4                NaN   5000000
# 5                NaN  12000000
# 6                LSU   1170960
# 7            Gonzaga   2165160
# 8         Louisville   1824360
# 9     Oklahoma State   3431040

# %%
nba['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
len(nba['Position'].unique())
# Out:
# 5

# %%
nba['Position'].nunique()
# Out:
# 5

# %% [markdown]
# ## Filter A `DataFrame` Based On A Condition

# %%
filter1 = nba['Team'] == 'Chicago Bulls'
nba[filter1]
# Out:
#                   Name           Team  Number Position  Age Height  Weight  \
# 151   Cameron Bairstow  Chicago Bulls    41.0       PF   25    6-9   250.0
# 152       Aaron Brooks  Chicago Bulls     0.0       PG   31    6-0   161.0
# 153       Jimmy Butler  Chicago Bulls    21.0       SG   26    6-7   220.0
# 154      Mike Dunleavy  Chicago Bulls    34.0       SG   35    6-9   230.0
# 155  Cristiano Felicio  Chicago Bulls     6.0       PF   23   6-10   275.0
# 156          Pau Gasol  Chicago Bulls    16.0        C   35    7-0   250.0
# 157         Taj Gibson  Chicago Bulls    22.0       PF   30    6-9   225.0
# 158     Justin Holiday  Chicago Bulls     7.0       SG   27    6-6   185.0
# 159     Doug McDermott  Chicago Bulls     3.0       SF   24    6-8   225.0
# 160     Nikola Mirotic  Chicago Bulls    44.0       PF   25   6-10   220.0
# 161      E'Twaun Moore  Chicago Bulls    55.0       SG   27    6-4   191.0
# 162        Joakim Noah  Chicago Bulls    13.0        C   31   6-11   232.0
# 163       Bobby Portis  Chicago Bulls     5.0       PF   21   6-11   230.0
# 164       Derrick Rose  Chicago Bulls     1.0       PG   27    6-3   190.0
# 165         Tony Snell  Chicago Bulls    20.0       SF   24    6-7   200.0
#
#         College    Salary
# 151  New Mexico    845059
# 152      Oregon   2250000
# 153   Marquette  16407500
# 154        Duke   4500000
# 155         NaN    525093
# 156         NaN   7448760
# 157         USC   8500000
# 158  Washington    947276
# 159   Creighton   2380440
# 160         NaN   5543725
# 161      Purdue   1015421
# 162     Florida  13400000
# 163    Arkansas   1391160
# 164     Memphis  20093064
# 165  New Mexico   1535880

# %% [markdown]
# ## Filter with More than One Condition (AND)

# %%
filter1 = nba['Team'] == 'Chicago Bulls'
filter2 = nba['Weight'] < 200.0

nba[filter1 & filter2]
# Out:
#                Name           Team  Number Position  Age Height  Weight  \
# 152    Aaron Brooks  Chicago Bulls     0.0       PG   31    6-0   161.0
# 158  Justin Holiday  Chicago Bulls     7.0       SG   27    6-6   185.0
# 161   E'Twaun Moore  Chicago Bulls    55.0       SG   27    6-4   191.0
# 164    Derrick Rose  Chicago Bulls     1.0       PG   27    6-3   190.0
#
#         College    Salary
# 152      Oregon   2250000
# 158  Washington    947276
# 161      Purdue   1015421
# 164     Memphis  20093064

# %%
nba.loc[nba['Age'] == 29, :]
# Out:
#                          Name                    Team  Number Position  Age  \
# 4               Jonas Jerebko          Boston Celtics     8.0       PF   29
# 5                Amir Johnson          Boston Celtics    90.0       PF   29
# 63            DeMarre Carroll         Toronto Raptors     5.0       SF   29
# 65              James Johnson         Toronto Raptors     3.0       PF   29
# 73             Jason Thompson         Toronto Raptors     1.0       PF   29
# 92                 Jeff Ayres    Los Angeles Clippers    19.0       PF   29
# 95                 Jeff Green    Los Angeles Clippers     8.0       SF   29
# 99   Luc Richard Mbah a Moute    Los Angeles Clippers    12.0       PF   29
# 111               Roy Hibbert      Los Angeles Lakers    17.0        C   29
# 118            Louis Williams      Los Angeles Lakers    23.0       SG   29
# 146                  Rudy Gay        Sacramento Kings     8.0       SF   29
# 176            Timofey Mozgov     Cleveland Cavaliers    20.0        C   29
# 182               Aron Baynes         Detroit Pistons    12.0        C   29
# 204               Ian Mahinmi          Indiana Pacers    28.0        C   29
# 205                C.J. Miles          Indiana Pacers     0.0       SF   29
# 225           Greivis Vasquez         Milwaukee Bucks    21.0       PG   29
# 233           Wesley Matthews        Dallas Mavericks    23.0       SG   29
# 235               Salah Mejri        Dallas Mavericks    50.0        C   29
# 264             Jordan Farmar       Memphis Grizzlies     4.0       PG   29
# 277                 Omer Asik    New Orleans Pelicans     3.0        C   29
# 280          Dante Cunningham    New Orleans Pelicans    44.0       PF   29
# 287                Alonzo Gee    New Orleans Pelicans    15.0       SF   29
# 337           Marvin Williams       Charlotte Hornets     2.0       PF   29
# 346            Josh McRoberts              Miami Heat     4.0       PF   29
# 358            Ersan Ilyasova           Orlando Magic     7.0       PF   29
# 381           Marcus Thornton      Washington Wizards    15.0       SF   29
# 386           Wilson Chandler          Denver Nuggets    21.0       SF   29
# 408              Damjan Rudez  Minnesota Timberwolves    10.0       SF   29
#
#     Height  Weight           College    Salary
# 4     6-10   231.0               NaN   5000000
# 5      6-9   240.0               NaN  12000000
# 63     6-8   212.0          Missouri  13600000
# 65     6-9   250.0       Wake Forest   2500000
# 73    6-11   250.0             Rider    245177
# 92     6-9   250.0     Arizona State    111444
# 95     6-9   235.0        Georgetown   9650000
# 99     6-8   230.0              UCLA    947276
# 111    7-2   270.0        Georgetown  15592217
# 118    6-1   175.0               NaN   7000000
# 146    6-8   230.0       Connecticut  12403101
# 176    7-1   275.0               NaN   4950000
# 182   6-10   260.0  Washington State   6500000
# 204   6-11   250.0               NaN   4000000
# 205    6-6   231.0               NaN   4394225
# 225    6-6   217.0          Maryland   6600000
# 233    6-5   220.0         Marquette  16407500
# 235    7-2   245.0               NaN    525093
# 264    6-2   180.0              UCLA         0
# 277    7-0   255.0               NaN   9213483
# 280    6-8   230.0         Villanova   2850000
# 287    6-6   225.0           Alabama   1320000
# 337    6-9   237.0    North Carolina   7000000
# 346   6-10   240.0              Duke   5543725
# 358   6-10   235.0               NaN   7900000
# 381    6-4   205.0               LSU    200600
# 386    6-8   225.0            DePaul  10449438
# 408    6-9   230.0               NaN   1149500

# %% [markdown]
# ## Filter with More than One Condition (OR)

# %%
filter1 = nba['Team'] == 'New York Knicks'
filter2 = nba['Weight'] < 180
nba[filter1 | filter2]
# Out:
#                        Name                    Team  Number Position  Age  \
# 22             Shane Larkin           Brooklyn Nets     0.0       PG   23
# 30            Arron Afflalo         New York Knicks     4.0       SG   30
# 31             Lou Amundson         New York Knicks    17.0       PF   33
# 32   Thanasis Antetokounmpo         New York Knicks    43.0       SF   23
# 33          Carmelo Anthony         New York Knicks     7.0       SF   32
# 34            Jose Calderon         New York Knicks     3.0       PG   34
# 35         Cleanthony Early         New York Knicks    11.0       SF   25
# 36        Langston Galloway         New York Knicks     2.0       SG   24
# 37             Jerian Grant         New York Knicks    13.0       PG   23
# 38              Robin Lopez         New York Knicks     8.0        C   28
# 39             Kyle O'Quinn         New York Knicks     9.0       PF   26
# 40       Kristaps Porzingis         New York Knicks     6.0       PF   20
# 41           Kevin Seraphin         New York Knicks     1.0        C   26
# 42             Lance Thomas         New York Knicks    42.0       SF   28
# 43            Sasha Vujacic         New York Knicks    18.0       SG   32
# 44         Derrick Williams         New York Knicks    23.0       PF   25
# 45              Tony Wroten         New York Knicks     5.0       SG   23
# 57                Ish Smith      Philadelphia 76ers     1.0       PG   27
# 79                Ian Clark   Golden State Warriors    21.0       SG   25
# 100              Chris Paul    Los Angeles Clippers     3.0       PG   31
# 118          Louis Williams      Los Angeles Lakers    23.0       SG   29
# 130            Phil Pressey            Phoenix Suns    25.0       PG   25
# 142         Darren Collison        Sacramento Kings     7.0       PG   28
# 152            Aaron Brooks           Chicago Bulls     0.0       PG   31
# 175            Jordan McRae     Cleveland Cavaliers    12.0       SG   25
# 183             Steve Blake         Detroit Pistons    22.0       PG   36
# 262             Mike Conley       Memphis Grizzlies    11.0       PG   28
# 263            Bryce Cotton       Memphis Grizzlies     8.0       PG   23
# 279             Norris Cole    New Orleans Pelicans    30.0       PG   27
# 286             Tim Frazier    New Orleans Pelicans     2.0       PG   25
# 318         Dennis Schroder           Atlanta Hawks    17.0       PG   22
# 350           Briante Weber              Miami Heat    12.0       PG   23
# 359        Brandon Jennings           Orlando Magic    55.0       PG   26
# 361          Shabazz Napier           Orlando Magic    13.0       PG   24
# 367             C.J. Watson           Orlando Magic    32.0       PG   32
# 385             Will Barton          Denver Nuggets     5.0       SF   25
# 440           Brian Roberts  Portland Trail Blazers     2.0       PG   30
# 454               Raul Neto               Utah Jazz    25.0       PG   24
#
#     Height  Weight                College    Salary
# 22    5-11   175.0             Miami (FL)   1500000
# 30     6-5   210.0                   UCLA   8000000
# 31     6-9   220.0                   UNLV   1635476
# 32     6-7   205.0                    NaN     30888
# 33     6-8   240.0               Syracuse  22875000
# 34     6-3   200.0                    NaN   7402812
# 35     6-8   210.0          Wichita State    845059
# 36     6-2   200.0         Saint Joseph's    845059
# 37     6-4   195.0             Notre Dame   1572360
# 38     7-0   255.0               Stanford  12650000
# 39    6-10   250.0          Norfolk State   3750000
# 40     7-3   240.0                    NaN   4131720
# 41    6-10   278.0                    NaN   2814000
# 42     6-8   235.0                   Duke   1636842
# 43     6-7   195.0                    NaN    947276
# 44     6-8   240.0                Arizona   4000000
# 45     6-6   205.0             Washington    167406
# 57     6-0   175.0            Wake Forest    947276
# 79     6-3   175.0                Belmont    947276
# 100    6-0   175.0            Wake Forest  21468695
# 118    6-1   175.0                    NaN   7000000
# 130   5-11   175.0               Missouri     55722
# 142    6-0   175.0                   UCLA   5013559
# 152    6-0   161.0                 Oregon   2250000
# 175    6-5   179.0              Tennessee    111196
# 183    6-3   172.0               Maryland   2170465
# 262    6-1   175.0             Ohio State   9588426
# 263    6-1   165.0             Providence    700902
# 279    6-2   175.0        Cleveland State   3036927
# 286    6-1   170.0             Penn State    845059
# 318    6-1   172.0                    NaN   1763400
# 350    6-2   165.0  Virginia Commonwealth         0
# 359    6-1   169.0                    NaN   8344497
# 361    6-1   175.0            Connecticut   1294440
# 367    6-2   175.0              Tennessee   5000000
# 385    6-6   175.0                Memphis   3533333
# 440    6-1   173.0                 Dayton   2854940
# 454    6-1   179.0                    NaN    900000

# %%
filter1 = nba['Name'] == 'Kobe Bryant'
filter2 = nba['Team'] == 'Los Angeles Lakers'
filter3 = nba['Salary'] < 200000

nba[(filter1 & filter2) | filter3]
# Out:
#                        Name                    Team  Number Position  Age  \
# 2              John Holland          Boston Celtics    30.0       SG   27
# 21          Sean Kilpatrick           Brooklyn Nets     6.0       SG   26
# 32   Thanasis Antetokounmpo         New York Knicks    43.0       SF   23
# 45              Tony Wroten         New York Knicks     5.0       SG   23
# 46              Elton Brand      Philadelphia 76ers    42.0       PF   37
# 92               Jeff Ayres    Los Angeles Clippers    19.0       PF   29
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF   37
# 130            Phil Pressey            Phoenix Suns    25.0       PG   25
# 135           Alan Williams            Phoenix Suns    15.0        C   23
# 171           Dahntay Jones     Cleveland Cavaliers    30.0       SG   35
# 175            Jordan McRae     Cleveland Cavaliers    12.0       SG   25
# 184           Lorenzo Brown         Detroit Pistons    17.0       PG   25
# 264           Jordan Farmar       Memphis Grizzlies     4.0       PG   29
# 269            Ray McCallum       Memphis Grizzlies     5.0       PG   24
# 270          Xavier Munford       Memphis Grizzlies    14.0       PG   24
# 273          Alex Stepheson       Memphis Grizzlies    35.0       PF   28
# 282      Bryce Dejean-Jones    New Orleans Pelicans    31.0       SG   23
# 291         Orlando Johnson    New Orleans Pelicans     0.0       SG   27
# 326         Jorge Gutierrez       Charlotte Hornets    12.0       PG   27
# 350           Briante Weber              Miami Heat    12.0       PG   23
# 353           Dorell Wright              Miami Heat    11.0       SF   30
# 397            Axel Toupane          Denver Nuggets     6.0       SG   23
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF   25
#
#     Height  Weight                College    Salary
# 2      6-5   205.0      Boston University         0
# 21     6-4   219.0             Cincinnati    134215
# 32     6-7   205.0                    NaN     30888
# 45     6-6   205.0             Washington    167406
# 46     6-9   254.0                   Duke         0
# 92     6-9   250.0          Arizona State    111444
# 109    6-6   212.0                    NaN  25000000
# 130   5-11   175.0               Missouri     55722
# 135    6-8   260.0       UC Santa Barbara     83397
# 171    6-6   225.0                   Duke         0
# 175    6-5   179.0              Tennessee    111196
# 184    6-5   189.0   North Carolina State    111444
# 264    6-2   180.0                   UCLA         0
# 269    6-3   190.0                Detroit         0
# 270    6-3   180.0           Rhode Island         0
# 273   6-10   270.0                    USC         0
# 282    6-6   203.0             Iowa State    169883
# 291    6-5   220.0       UC Santa Barbara     55722
# 326    6-3   189.0             California    189455
# 350    6-2   165.0  Virginia Commonwealth         0
# 353    6-9   205.0                    NaN         0
# 397    6-7   210.0                    NaN         0
# 409   6-10   250.0           Fresno State         0

# %% [markdown]
# ## Retrieve Rows by Index Label with `.loc[]`

# %%
nba = pd.read_csv("Data/nba.csv")
nba_two = nba.set_index('Name', inplace=False)
nba_two.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
nba.set_index('Name', inplace=True)
nba.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
nba.reset_index(drop=True, inplace=True)
nba.head()
# Out:
#              Team  Number Position   Age Height  Weight            College  \
# 0  Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas
# 1  Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette
# 2  Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University
# 3  Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State
# 4  Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN
#
#       Salary
# 0  7730337.0
# 1  6796117.0
# 2        NaN
# 3  1148640.0
# 4  5000000.0

# %%
# another method to set index

nba.head(10)
# Out:
#              Team  Number Position   Age Height  Weight            College  \
# 0  Boston Celtics     0.0       PG  25.0    6-2   180.0              Texas
# 1  Boston Celtics    99.0       SF  25.0    6-6   235.0          Marquette
# 2  Boston Celtics    30.0       SG  27.0    6-5   205.0  Boston University
# 3  Boston Celtics    28.0       SG  22.0    6-5   185.0      Georgia State
# 4  Boston Celtics     8.0       PF  29.0   6-10   231.0                NaN
# 5  Boston Celtics    90.0       PF  29.0    6-9   240.0                NaN
# 6  Boston Celtics    55.0       PF  21.0    6-8   235.0                LSU
# 7  Boston Celtics    41.0        C  25.0    7-0   238.0            Gonzaga
# 8  Boston Celtics    12.0       PG  22.0    6-2   190.0         Louisville
# 9  Boston Celtics    36.0       PG  22.0    6-4   220.0     Oklahoma State
#
#        Salary
# 0   7730337.0
# 1   6796117.0
# 2         NaN
# 3   1148640.0
# 4   5000000.0
# 5  12000000.0
# 6   1170960.0
# 7   2165160.0
# 8   1824360.0
# 9   3431040.0

# %%
nba = pd.read_csv('Data/nba.csv', index_col='Name')
nba.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
nba[5:10]
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk   Boston Celtics    41.0        C  25.0    7-0   238.0
# Terry Rozier   Boston Celtics    12.0       PG  22.0    6-2   190.0
# Marcus Smart   Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#                       College      Salary
# Name
# Amir Johnson              NaN  12000000.0
# Jordan Mickey             LSU   1170960.0
# Kelly Olynyk          Gonzaga   2165160.0
# Terry Rozier       Louisville   1824360.0
# Marcus Smart   Oklahoma State   3431040.0

# %%
nba.loc['Amir Johnson']
# Out:
# Team        Boston Celtics
# Number                90.0
# Position                PF
# Age                   29.0
# Height                 6-9
# Weight               240.0
# College                NaN
# Salary          12000000.0
# Name: Amir Johnson, dtype: object

# %%
nba.sort_index(inplace=True)
nba.head()
# Out:
#                                   Team  Number Position   Age Height  Weight  \
# Name
# Aaron Brooks             Chicago Bulls     0.0       PG  31.0    6-0   161.0
# Aaron Gordon             Orlando Magic     0.0       PF  20.0    6-9   220.0
# Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6   210.0
# Adreian Payne   Minnesota Timberwolves    33.0       PF  25.0   6-10   237.0
# Al Horford               Atlanta Hawks    15.0        C  30.0   6-10   245.0
#
#                        College      Salary
# Name
# Aaron Brooks            Oregon   2250000.0
# Aaron Gordon           Arizona   4171680.0
# Aaron Harrison        Kentucky    525093.0
# Adreian Payne   Michigan State   1938840.0
# Al Horford             Florida  12000000.0

# %%
'Michael Jordan' in nba.index
# Out:
# False

# %% [markdown]
# ### Slicing

# %%
nba.loc['Blake Griffin': 'Bojan Bogdanovic']
# Out:
#                                   Team  Number Position   Age Height  Weight  \
# Name
# Blake Griffin     Los Angeles Clippers    32.0       PF  27.0   6-10   251.0
# Boban Marjanovic     San Antonio Spurs    40.0        C  27.0    7-3   290.0
# Bobby Portis             Chicago Bulls     5.0       PF  21.0   6-11   230.0
# Bojan Bogdanovic         Brooklyn Nets    44.0       SG  27.0    6-8   216.0
#
#                    College      Salary
# Name
# Blake Griffin     Oklahoma  18907726.0
# Boban Marjanovic       NaN   1200000.0
# Bobby Portis      Arkansas   1391160.0
# Bojan Bogdanovic       NaN   3425510.0

# %%
nba[38:42]
# Out:
#                                   Team  Number Position   Age Height  Weight  \
# Name
# Blake Griffin     Los Angeles Clippers    32.0       PF  27.0   6-10   251.0
# Boban Marjanovic     San Antonio Spurs    40.0        C  27.0    7-3   290.0
# Bobby Portis             Chicago Bulls     5.0       PF  21.0   6-11   230.0
# Bojan Bogdanovic         Brooklyn Nets    44.0       SG  27.0    6-8   216.0
#
#                    College      Salary
# Name
# Blake Griffin     Oklahoma  18907726.0
# Boban Marjanovic       NaN   1200000.0
# Bobby Portis      Arkansas   1391160.0
# Bojan Bogdanovic       NaN   3425510.0

# %%
nba.loc[['Andrew Bogut', 'Carmelo Anthony']]
# Out:
#                                   Team  Number Position   Age Height  Weight  \
# Name
# Andrew Bogut     Golden State Warriors    12.0        C  31.0    7-0   260.0
# Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8   240.0
#
#                   College      Salary
# Name
# Andrew Bogut         Utah  13800000.0
# Carmelo Anthony  Syracuse  22875000.0

# %%
nba.iloc[[22, 63]]
# Out:
#                                   Team  Number Position   Age Height  Weight  \
# Name
# Andrew Bogut     Golden State Warriors    12.0        C  31.0    7-0   260.0
# Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8   240.0
#
#                   College      Salary
# Name
# Andrew Bogut         Utah  13800000.0
# Carmelo Anthony  Syracuse  22875000.0

# %%
pd.to_numeric(nba['Salary'], errors='coerce')

nba.apply(lambda x: pd.to_numeric(x, errors='coerce'))
# Out:
#                  Team  Number  Position   Age  Height  Weight  College  \
# Name
# Aaron Brooks      NaN     0.0       NaN  31.0     NaN   161.0      NaN
# Aaron Gordon      NaN     0.0       NaN  20.0     NaN   220.0      NaN
# Aaron Harrison    NaN     9.0       NaN  21.0     NaN   210.0      NaN
# Adreian Payne     NaN    33.0       NaN  25.0     NaN   237.0      NaN
# Al Horford        NaN    15.0       NaN  30.0     NaN   245.0      NaN
# ...               ...     ...       ...   ...     ...     ...      ...
# Wilson Chandler   NaN    21.0       NaN  29.0     NaN   225.0      NaN
# Xavier Munford    NaN    14.0       NaN  24.0     NaN   180.0      NaN
# Zach LaVine       NaN     8.0       NaN  21.0     NaN   189.0      NaN
# Zach Randolph     NaN    50.0       NaN  34.0     NaN   260.0      NaN
# Zaza Pachulia     NaN    27.0       NaN  32.0     NaN   275.0      NaN
#
#                      Salary
# Name
# Aaron Brooks      2250000.0
# Aaron Gordon      4171680.0
# Aaron Harrison     525093.0
# Adreian Payne     1938840.0
# Al Horford       12000000.0
# ...                     ...
# Wilson Chandler  10449438.0
# Xavier Munford          NaN
# Zach LaVine       2148360.0
# Zach Randolph     9638555.0
# Zaza Pachulia     5200000.0
#
# [457 rows x 8 columns]

# %%
nba.reset_index(drop=True, inplace=True)
nba
# Out:
#                        Team  Number Position   Age Height  Weight  \
# 0             Chicago Bulls     0.0       PG  31.0    6-0   161.0
# 1             Orlando Magic     0.0       PF  20.0    6-9   220.0
# 2         Charlotte Hornets     9.0       SG  21.0    6-6   210.0
# 3    Minnesota Timberwolves    33.0       PF  25.0   6-10   237.0
# 4             Atlanta Hawks    15.0        C  30.0   6-10   245.0
# ..                      ...     ...      ...   ...    ...     ...
# 452          Denver Nuggets    21.0       SF  29.0    6-8   225.0
# 453       Memphis Grizzlies    14.0       PG  24.0    6-3   180.0
# 454  Minnesota Timberwolves     8.0       PG  21.0    6-5   189.0
# 455       Memphis Grizzlies    50.0       PF  34.0    6-9   260.0
# 456        Dallas Mavericks    27.0        C  32.0   6-11   275.0
#
#             College      Salary
# 0            Oregon   2250000.0
# 1           Arizona   4171680.0
# 2          Kentucky    525093.0
# 3    Michigan State   1938840.0
# 4           Florida  12000000.0
# ..              ...         ...
# 452          DePaul  10449438.0
# 453    Rhode Island         NaN
# 454            UCLA   2148360.0
# 455  Michigan State   9638555.0
# 456             NaN   5200000.0
#
# [457 rows x 8 columns]

# %% [markdown]
# # <br> END OF LECTURE 1 ON PANDAS </br>
#
# # <b> START OF LECTURE 2 ON PANDAS </b>

# %% [markdown]
# ## Retrieve Row(s) by Index Position with `iloc[]`

# %%
nba = pd.read_csv("Data/nba.csv")
nba.head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.loc[1]
nba.iloc[1]
# Out:
# Name           Jae Crowder
# Team        Boston Celtics
# Number                99.0
# Position                SF
# Age                   25.0
# Height                 6-6
# Weight               235.0
# College          Marquette
# Salary           6796117.0
# Name: 1, dtype: object

# %%
nba.iloc[[1,3]]
nba[:4]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
nba.head(10)
nba.iloc[4:8]
nba[4:8]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#    College      Salary
# 4      NaN   5000000.0
# 5      NaN  12000000.0
# 6      LSU   1170960.0
# 7  Gonzaga   2165160.0

# %%
nba[440:]
# Out:
#                Name                    Team  Number Position   Age Height  \
# 440   Brian Roberts  Portland Trail Blazers     2.0       PG  30.0    6-1
# 441     Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0    6-9
# 442   Trevor Booker               Utah Jazz    33.0       PF  28.0    6-8
# 443      Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 444      Alec Burks               Utah Jazz    10.0       SG  24.0    6-6
# 445      Dante Exum               Utah Jazz    11.0       PG  20.0    6-6
# 446  Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
# 447     Rudy Gobert               Utah Jazz    27.0        C  23.0    7-1
# 448  Gordon Hayward               Utah Jazz    20.0       SF  26.0    6-8
# 449     Rodney Hood               Utah Jazz     5.0       SG  23.0    6-8
# 450      Joe Ingles               Utah Jazz     2.0       SF  28.0    6-8
# 451   Chris Johnson               Utah Jazz    23.0       SF  26.0    6-6
# 452      Trey Lyles               Utah Jazz    41.0       PF  20.0   6-10
# 453    Shelvin Mack               Utah Jazz     8.0       PG  26.0    6-3
# 454       Raul Neto               Utah Jazz    25.0       PG  24.0    6-1
# 455    Tibor Pleiss               Utah Jazz    21.0        C  26.0    7-3
# 456     Jeff Withey               Utah Jazz    24.0        C  26.0    7-0
#
#      Weight       College      Salary
# 440   173.0        Dayton   2854940.0
# 441   240.0       Indiana   2637720.0
# 442   228.0       Clemson   4775000.0
# 443   191.0      Michigan   2658240.0
# 444   214.0      Colorado   9463484.0
# 445   190.0           NaN   3777720.0
# 446   265.0  Georgia Tech  12000000.0
# 447   245.0           NaN   1175880.0
# 448   226.0        Butler  15409570.0
# 449   206.0          Duke   1348440.0
# 450   226.0           NaN   2050000.0
# 451   206.0        Dayton    981348.0
# 452   234.0      Kentucky   2239800.0
# 453   203.0        Butler   2433333.0
# 454   179.0           NaN    900000.0
# 455   256.0           NaN   2900000.0
# 456   231.0        Kansas    947276.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba = pd.read_csv("Data/nba.csv", index_col='Name')
nba.sort_index(inplace = True)
nba.head(22)
# Out:
#                                      Team  Number Position   Age Height  \
# Name
# Aaron Brooks                Chicago Bulls     0.0       PG  31.0    6-0
# Aaron Gordon                Orlando Magic     0.0       PF  20.0    6-9
# Aaron Harrison          Charlotte Hornets     9.0       SG  21.0    6-6
# Adreian Payne      Minnesota Timberwolves    33.0       PF  25.0   6-10
# Al Horford                  Atlanta Hawks    15.0        C  30.0   6-10
# Al Jefferson            Charlotte Hornets    25.0        C  31.0   6-10
# Al-Farouq Aminu    Portland Trail Blazers     8.0       SF  25.0    6-9
# Alan Anderson          Washington Wizards     6.0       SG  33.0    6-6
# Alan Williams                Phoenix Suns    15.0        C  23.0    6-8
# Alec Burks                      Utah Jazz    10.0       SG  24.0    6-6
# Alex Len                     Phoenix Suns    21.0        C  22.0    7-1
# Alex Stepheson          Memphis Grizzlies    35.0       PF  28.0   6-10
# Alexis Ajinca        New Orleans Pelicans    42.0        C  28.0    7-2
# Allen Crabbe       Portland Trail Blazers    23.0       SG  24.0    6-6
# Alonzo Gee           New Orleans Pelicans    15.0       SF  29.0    6-6
# Amar'e Stoudemire              Miami Heat     5.0       PF  33.0   6-10
# Amir Johnson               Boston Celtics    90.0       PF  29.0    6-9
# Anderson Varejao    Golden State Warriors    18.0       PF  33.0   6-11
# Andre Drummond            Detroit Pistons     0.0        C  22.0   6-11
# Andre Iguodala      Golden State Warriors     9.0       SF  32.0    6-6
# Andre Miller            San Antonio Spurs    24.0       PG  40.0    6-3
# Andre Roberson      Oklahoma City Thunder    21.0       SG  24.0    6-7
#
#                    Weight           College      Salary
# Name
# Aaron Brooks        161.0            Oregon   2250000.0
# Aaron Gordon        220.0           Arizona   4171680.0
# Aaron Harrison      210.0          Kentucky    525093.0
# Adreian Payne       237.0    Michigan State   1938840.0
# Al Horford          245.0           Florida  12000000.0
# Al Jefferson        289.0               NaN  13500000.0
# Al-Farouq Aminu     215.0       Wake Forest   8042895.0
# Alan Anderson       220.0    Michigan State   4000000.0
# Alan Williams       260.0  UC Santa Barbara     83397.0
# Alec Burks          214.0          Colorado   9463484.0
# Alex Len            260.0          Maryland   3807120.0
# Alex Stepheson      270.0               USC         NaN
# Alexis Ajinca       248.0               NaN   4389607.0
# Allen Crabbe        210.0        California    947276.0
# Alonzo Gee          225.0           Alabama   1320000.0
# Amar'e Stoudemire   245.0               NaN    947276.0
# Amir Johnson        240.0               NaN  12000000.0
# Anderson Varejao    273.0               NaN    289755.0
# Andre Drummond      279.0       Connecticut   3272091.0
# Andre Iguodala      215.0           Arizona  11710456.0
# Andre Miller        200.0              Utah    250750.0
# Andre Roberson      210.0          Colorado   1210800.0

# %%
nba.iloc[[5, 10, 15, 20]]
nba.loc[['Al Jefferson', 'Alex Len', 'Amar\'e Stoudemire', 'Andre Miller']]
# Out:
#                                 Team  Number Position   Age Height  Weight  \
# Name
# Al Jefferson       Charlotte Hornets    25.0        C  31.0   6-10   289.0
# Alex Len                Phoenix Suns    21.0        C  22.0    7-1   260.0
# Amar'e Stoudemire         Miami Heat     5.0       PF  33.0   6-10   245.0
# Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3   200.0
#
#                     College      Salary
# Name
# Al Jefferson            NaN  13500000.0
# Alex Len           Maryland   3807120.0
# Amar'e Stoudemire       NaN    947276.0
# Andre Miller           Utah    250750.0

# %%
nba.iloc[100:300]
nba.iloc[100:300, [0, 2, 7]]
# Out:
#                                      Team Position      Salary
# Name
# DeAndre Jordan       Los Angeles Clippers        C  19689000.0
# DeMar DeRozan             Toronto Raptors       SG  10050000.0
# DeMarcus Cousins         Sacramento Kings        C  15851950.0
# DeMarre Carroll           Toronto Raptors       SF  13600000.0
# Delon Wright              Toronto Raptors       PG   1509360.0
# ...                                   ...      ...         ...
# Markel Brown                Brooklyn Nets       SG    845059.0
# Markieff Morris        Washington Wizards       PF   8000000.0
# Marreese Speights   Golden State Warriors        C   3815000.0
# Marvin Williams         Charlotte Hornets       PF   7000000.0
# Mason Plumlee      Portland Trail Blazers        C   1415520.0
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Create a new column & get biggest values

# %%
nba = pd.read_csv("Data/nba.csv",
                  dtype={'Number': 'int', 'Age':'int'},
                  usecols=lambda title: 'Height' not in title,
                 )
nba.head()


# or
# Out:
#             Name            Team  Number Position  Age  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25   235.0
# 2   John Holland  Boston Celtics      30       SG   27   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['SalaryPerMonth'] = nba['Salary'] / 12
nba.head(10)
# Out:
#             Name            Team  Number Position  Age  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25   235.0
# 2   John Holland  Boston Celtics      30       SG   27   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   231.0
# 5   Amir Johnson  Boston Celtics      90       PF   29   240.0
# 6  Jordan Mickey  Boston Celtics      55       PF   21   235.0
# 7   Kelly Olynyk  Boston Celtics      41        C   25   238.0
# 8   Terry Rozier  Boston Celtics      12       PG   22   190.0
# 9   Marcus Smart  Boston Celtics      36       PG   22   220.0
#
#              College      Salary  SalaryPerMonth
# 0              Texas   7730337.0   644194.750000
# 1          Marquette   6796117.0   566343.083333
# 2  Boston University         NaN             NaN
# 3      Georgia State   1148640.0    95720.000000
# 4                NaN   5000000.0   416666.666667
# 5                NaN  12000000.0  1000000.000000
# 6                LSU   1170960.0    97580.000000
# 7            Gonzaga   2165160.0   180430.000000
# 8         Louisville   1824360.0   152030.000000
# 9     Oklahoma State   3431040.0   285920.000000

# %%
nba = nba.assign(SalaryPerMonthTwo = nba['Salary'] / 12)
nba.head()
# Out:
#             Name            Team  Number Position  Age  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25   235.0
# 2   John Holland  Boston Celtics      30       SG   27   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   231.0
#
#              College     Salary  SalaryPerMonth  SalaryPerMonthTwo
# 0              Texas  7730337.0   644194.750000      644194.750000
# 1          Marquette  6796117.0   566343.083333      566343.083333
# 2  Boston University        NaN             NaN                NaN
# 3      Georgia State  1148640.0    95720.000000       95720.000000
# 4                NaN  5000000.0   416666.666667      416666.666667

# %%
nba['Salary'].max()
nba['Salary'].fillna(0).astype(int)
# Out:
# 0      7730337
# 1      6796117
# 2            0
# 3      1148640
# 4      5000000
#         ...
# 452    2239800
# 453    2433333
# 454     900000
# 455    2900000
# 456     947276
# Name: Salary, Length: 457, dtype: int64

# %%
nba['Salary'].idxmax()
nba.loc[109]
nba.iloc[109]
# Out:
# Name                        Kobe Bryant
# Team                 Los Angeles Lakers
# Number                               24
# Position                             SF
# Age                                  37
# Weight                            212.0
# College                             NaN
# Salary                       25000000.0
# SalaryPerMonth           2083333.333333
# SalaryPerMonthTwo        2083333.333333
# Name: 109, dtype: object

# %% [markdown]
# ## Set filters in `DataFrame` through `loc`

# %%
nba = pd.read_csv("Data/nba.csv")
nba.set_index("Name", inplace = True)
nba.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %%
filter1 = nba['Team'] == 'Chicago Bulls'

nba[filter1]
nba[nba['Team'] == 'Chicago Bulls']
nba.loc[nba['Team'] == 'Chicago Bulls']
# Out:
#                             Team  Number Position   Age Height  Weight  \
# Name
# Cameron Bairstow   Chicago Bulls    41.0       PF  25.0    6-9   250.0
# Aaron Brooks       Chicago Bulls     0.0       PG  31.0    6-0   161.0
# Jimmy Butler       Chicago Bulls    21.0       SG  26.0    6-7   220.0
# Mike Dunleavy      Chicago Bulls    34.0       SG  35.0    6-9   230.0
# Cristiano Felicio  Chicago Bulls     6.0       PF  23.0   6-10   275.0
# Pau Gasol          Chicago Bulls    16.0        C  35.0    7-0   250.0
# Taj Gibson         Chicago Bulls    22.0       PF  30.0    6-9   225.0
# Justin Holiday     Chicago Bulls     7.0       SG  27.0    6-6   185.0
# Doug McDermott     Chicago Bulls     3.0       SF  24.0    6-8   225.0
# Nikola Mirotic     Chicago Bulls    44.0       PF  25.0   6-10   220.0
# E'Twaun Moore      Chicago Bulls    55.0       SG  27.0    6-4   191.0
# Joakim Noah        Chicago Bulls    13.0        C  31.0   6-11   232.0
# Bobby Portis       Chicago Bulls     5.0       PF  21.0   6-11   230.0
# Derrick Rose       Chicago Bulls     1.0       PG  27.0    6-3   190.0
# Tony Snell         Chicago Bulls    20.0       SF  24.0    6-7   200.0
#
#                       College      Salary
# Name
# Cameron Bairstow   New Mexico    845059.0
# Aaron Brooks           Oregon   2250000.0
# Jimmy Butler        Marquette  16407500.0
# Mike Dunleavy            Duke   4500000.0
# Cristiano Felicio         NaN    525093.0
# Pau Gasol                 NaN   7448760.0
# Taj Gibson                USC   8500000.0
# Justin Holiday     Washington    947276.0
# Doug McDermott      Creighton   2380440.0
# Nikola Mirotic            NaN   5543725.0
# E'Twaun Moore          Purdue   1015421.0
# Joakim Noah           Florida  13400000.0
# Bobby Portis         Arkansas   1391160.0
# Derrick Rose          Memphis  20093064.0
# Tony Snell         New Mexico   1535880.0

# %%
nba.loc[(nba['Team'] != 'Chicago Bulls') & (nba['Position'] == 'SG')].head(7)
# Out:
#                             Team  Number Position   Age Height  Weight  \
# Name
# John Holland      Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter       Boston Celtics    28.0       SG  22.0    6-5   185.0
# Evan Turner       Boston Celtics    11.0       SG  27.0    6-7   220.0
# James Young       Boston Celtics    13.0       SG  20.0    6-6   215.0
# Bojan Bogdanovic   Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# Markel Brown       Brooklyn Nets    22.0       SG  24.0    6-3   190.0
# Wayne Ellington    Brooklyn Nets    21.0       SG  28.0    6-4   200.0
#
#                             College     Salary
# Name
# John Holland      Boston University        NaN
# R.J. Hunter           Georgia State  1148640.0
# Evan Turner              Ohio State  3425510.0
# James Young                Kentucky  1749840.0
# Bojan Bogdanovic                NaN  3425510.0
# Markel Brown         Oklahoma State   845059.0
# Wayne Ellington      North Carolina  1500000.0

# %%
nba.loc[nba['Team'].isin(['Boston Celtics', 'Chicago Bulls'])]
# Out:
#                              Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley      Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder        Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland       Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter        Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko      Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson       Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey      Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk       Boston Celtics    41.0        C  25.0    7-0   238.0
# Terry Rozier       Boston Celtics    12.0       PG  22.0    6-2   190.0
# Marcus Smart       Boston Celtics    36.0       PG  22.0    6-4   220.0
# Jared Sullinger    Boston Celtics     7.0        C  24.0    6-9   260.0
# Isaiah Thomas      Boston Celtics     4.0       PG  27.0    5-9   185.0
# Evan Turner        Boston Celtics    11.0       SG  27.0    6-7   220.0
# James Young        Boston Celtics    13.0       SG  20.0    6-6   215.0
# Tyler Zeller       Boston Celtics    44.0        C  26.0    7-0   253.0
# Cameron Bairstow    Chicago Bulls    41.0       PF  25.0    6-9   250.0
# Aaron Brooks        Chicago Bulls     0.0       PG  31.0    6-0   161.0
# Jimmy Butler        Chicago Bulls    21.0       SG  26.0    6-7   220.0
# Mike Dunleavy       Chicago Bulls    34.0       SG  35.0    6-9   230.0
# Cristiano Felicio   Chicago Bulls     6.0       PF  23.0   6-10   275.0
# Pau Gasol           Chicago Bulls    16.0        C  35.0    7-0   250.0
# Taj Gibson          Chicago Bulls    22.0       PF  30.0    6-9   225.0
# Justin Holiday      Chicago Bulls     7.0       SG  27.0    6-6   185.0
# Doug McDermott      Chicago Bulls     3.0       SF  24.0    6-8   225.0
# Nikola Mirotic      Chicago Bulls    44.0       PF  25.0   6-10   220.0
# E'Twaun Moore       Chicago Bulls    55.0       SG  27.0    6-4   191.0
# Joakim Noah         Chicago Bulls    13.0        C  31.0   6-11   232.0
# Bobby Portis        Chicago Bulls     5.0       PF  21.0   6-11   230.0
# Derrick Rose        Chicago Bulls     1.0       PG  27.0    6-3   190.0
# Tony Snell          Chicago Bulls    20.0       SF  24.0    6-7   200.0
#
#                              College      Salary
# Name
# Avery Bradley                  Texas   7730337.0
# Jae Crowder                Marquette   6796117.0
# John Holland       Boston University         NaN
# R.J. Hunter            Georgia State   1148640.0
# Jonas Jerebko                    NaN   5000000.0
# Amir Johnson                     NaN  12000000.0
# Jordan Mickey                    LSU   1170960.0
# Kelly Olynyk                 Gonzaga   2165160.0
# Terry Rozier              Louisville   1824360.0
# Marcus Smart          Oklahoma State   3431040.0
# Jared Sullinger           Ohio State   2569260.0
# Isaiah Thomas             Washington   6912869.0
# Evan Turner               Ohio State   3425510.0
# James Young                 Kentucky   1749840.0
# Tyler Zeller          North Carolina   2616975.0
# Cameron Bairstow          New Mexico    845059.0
# Aaron Brooks                  Oregon   2250000.0
# Jimmy Butler               Marquette  16407500.0
# Mike Dunleavy                   Duke   4500000.0
# Cristiano Felicio                NaN    525093.0
# Pau Gasol                        NaN   7448760.0
# Taj Gibson                       USC   8500000.0
# Justin Holiday            Washington    947276.0
# Doug McDermott             Creighton   2380440.0
# Nikola Mirotic                   NaN   5543725.0
# E'Twaun Moore                 Purdue   1015421.0
# Joakim Noah                  Florida  13400000.0
# Bobby Portis                Arkansas   1391160.0
# Derrick Rose                 Memphis  20093064.0
# Tony Snell                New Mexico   1535880.0

# %%
nba.loc[nba['Team'] != 'Boston Celtics']
# or
# Out:
#                                   Team  Number Position   Age Height  Weight  \
# Name
# Bojan Bogdanovic         Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# Markel Brown             Brooklyn Nets    22.0       SG  24.0    6-3   190.0
# Wayne Ellington          Brooklyn Nets    21.0       SG  28.0    6-4   200.0
# Rondae Hollis-Jefferson  Brooklyn Nets    24.0       SG  21.0    6-7   220.0
# Jarrett Jack             Brooklyn Nets     2.0       PG  32.0    6-3   200.0
# ...                                ...     ...      ...   ...    ...     ...
# Trey Lyles                   Utah Jazz    41.0       PF  20.0   6-10   234.0
# Shelvin Mack                 Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto                    Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss                 Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey                  Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                                 College     Salary
# Name
# Bojan Bogdanovic                    NaN  3425510.0
# Markel Brown             Oklahoma State   845059.0
# Wayne Ellington          North Carolina  1500000.0
# Rondae Hollis-Jefferson         Arizona  1335480.0
# Jarrett Jack               Georgia Tech  6300000.0
# ...                                 ...        ...
# Trey Lyles                     Kentucky  2239800.0
# Shelvin Mack                     Butler  2433333.0
# Raul Neto                           NaN   900000.0
# Tibor Pleiss                        NaN  2900000.0
# Jeff Withey                      Kansas   947276.0
#
# [442 rows x 8 columns]

# %%
nba.loc[~nba['Team'].isin(['Boston Celtics'])].head(25)
# Out:
#                                     Team  Number Position   Age Height  \
# Name
# Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0    6-8
# Markel Brown               Brooklyn Nets    22.0       SG  24.0    6-3
# Wayne Ellington            Brooklyn Nets    21.0       SG  28.0    6-4
# Rondae Hollis-Jefferson    Brooklyn Nets    24.0       SG  21.0    6-7
# Jarrett Jack               Brooklyn Nets     2.0       PG  32.0    6-3
# Sergey Karasev             Brooklyn Nets    10.0       SG  22.0    6-7
# Sean Kilpatrick            Brooklyn Nets     6.0       SG  26.0    6-4
# Shane Larkin               Brooklyn Nets     0.0       PG  23.0   5-11
# Brook Lopez                Brooklyn Nets    11.0        C  28.0    7-0
# Chris McCullough           Brooklyn Nets     1.0       PF  21.0   6-11
# Willie Reed                Brooklyn Nets    33.0       PF  26.0   6-10
# Thomas Robinson            Brooklyn Nets    41.0       PF  25.0   6-10
# Henry Sims                 Brooklyn Nets    14.0        C  26.0   6-10
# Donald Sloan               Brooklyn Nets    15.0       PG  28.0    6-3
# Thaddeus Young             Brooklyn Nets    30.0       PF  27.0    6-8
# Arron Afflalo            New York Knicks     4.0       SG  30.0    6-5
# Lou Amundson             New York Knicks    17.0       PF  33.0    6-9
# Thanasis Antetokounmpo   New York Knicks    43.0       SF  23.0    6-7
# Carmelo Anthony          New York Knicks     7.0       SF  32.0    6-8
# Jose Calderon            New York Knicks     3.0       PG  34.0    6-3
# Cleanthony Early         New York Knicks    11.0       SF  25.0    6-8
# Langston Galloway        New York Knicks     2.0       SG  24.0    6-2
# Jerian Grant             New York Knicks    13.0       PG  23.0    6-4
# Robin Lopez              New York Knicks     8.0        C  28.0    7-0
# Kyle O'Quinn             New York Knicks     9.0       PF  26.0   6-10
#
#                          Weight         College      Salary
# Name
# Bojan Bogdanovic          216.0             NaN   3425510.0
# Markel Brown              190.0  Oklahoma State    845059.0
# Wayne Ellington           200.0  North Carolina   1500000.0
# Rondae Hollis-Jefferson   220.0         Arizona   1335480.0
# Jarrett Jack              200.0    Georgia Tech   6300000.0
# Sergey Karasev            208.0             NaN   1599840.0
# Sean Kilpatrick           219.0      Cincinnati    134215.0
# Shane Larkin              175.0      Miami (FL)   1500000.0
# Brook Lopez               275.0        Stanford  19689000.0
# Chris McCullough          200.0        Syracuse   1140240.0
# Willie Reed               220.0     Saint Louis    947276.0
# Thomas Robinson           237.0          Kansas    981348.0
# Henry Sims                248.0      Georgetown    947276.0
# Donald Sloan              205.0       Texas A&M    947276.0
# Thaddeus Young            221.0    Georgia Tech  11235955.0
# Arron Afflalo             210.0            UCLA   8000000.0
# Lou Amundson              220.0            UNLV   1635476.0
# Thanasis Antetokounmpo    205.0             NaN     30888.0
# Carmelo Anthony           240.0        Syracuse  22875000.0
# Jose Calderon             200.0             NaN   7402812.0
# Cleanthony Early          210.0   Wichita State    845059.0
# Langston Galloway         200.0  Saint Joseph's    845059.0
# Jerian Grant              195.0      Notre Dame   1572360.0
# Robin Lopez               255.0        Stanford  12650000.0
# Kyle O'Quinn              250.0   Norfolk State   3750000.0

# %% [markdown]
# ## Methods on the `.groupby()` method and `DataFrame` columns

# %%
nba = pd.read_csv("Data/nba.csv")
positions = nba.groupby(by='Position')
positions.get_group('SG')
positions.groups
# Out:
# {'C': [7, 10, 14, 23, 27, 38, 41, 49, 56, 61, 68, 74, 78, 81, 88, 91, 98, 107, 111, 117, 124, 128, 135, 141, 143, 147, 156, 162, 173, 176, 179, 181, 182, 188, 201, 204, 220, 224, 234, 235, 237, 251, 255, 265, 275, 277, 292, 296, 297, 298, 302, 312, 321, 322, 330, 331, 338, 351, 354, 366, 373, 374, 375, 390, 391, 395, 399, 405, 410, 412, 418, 420, 431, 434, 439, 447, 455, 456], 'PF': [4, 5, 6, 24, 25, 26, 29, 31, 39, 40, 44, 46, 51, 52, 55, 60, 65, 69, 72, 73, 82, 90, 92, 96, 99, 106, 113, 114, 115, 129, 132, 145, 149, 151, 155, 157, 160, 163, 167, 174, 194, 195, 196, 197, 208, 209, 216, 222, 223, 232, 236, 239, 240, 246, 250, 252, 254, 259, 266, 268, 271, 273, 274, 276, 280, 281, 294, 308, 313, 315, 316, 319, 327, 329, 337, 339, 343, 346, 348, 356, 358, 362, 365, 372, 376, 383, 387, 398, 400, 404, 409, 413, 417, 419, 427, 435, 441, 442, 446, 452], 'PG': [0, 8, 9, 11, 19, 22, 28, 34, 37, 47, 53, 54, 57, 66, 67, 75, 80, 84, 100, 102, 104, 110, 112, 116, 121, 127, 130, 131, 142, 150, 152, 164, 166, 168, 180, 183, 184, 187, 191, 200, 203, 207, 210, 212, 213, 215, 225, 228, 230, 231, 241, 244, 248, 262, 263, 264, 269, 270, 279, 283, 286, 290, 304, 305, 306, 318, 323, 326, 335, 336, 341, 350, 359, 361, 364, 367, 379, 382, 384, 393, 394, 401, 402, 407, 422, 426, 436, 440, 443, 445, 453, 454], 'SF': [1, 32, 33, 35, 42, 48, 50, 62, 63, 71, 77, 83, 85, 86, 87, 94, 95, 97, 101, 108, 109, 119, 120, 123, 133, 134, 136, 139, 140, 146, 159, 165, 169, 170, 185, 189, 190, 192, 199, 202, 205, 211, 217, 221, 229, 238, 242, 243, 247, 260, 267, 272, 278, 284, 287, 293, 295, 301, 309, 320, 332, 340, 342, 344, 352, 353, 360, 370, 377, 378, 381, 385, 386, 388, 403, 406, 408, 414, 416, 424, 428, 432, 448, 450, 451], 'SG': [2, 3, 12, 13, 15, 16, 17, 18, 20, 21, 30, 36, 43, 45, 58, 59, 64, 70, 76, 79, 89, 93, 103, 105, 118, 122, 125, 126, 137, 138, 144, 148, 153, 154, 158, 161, 171, 172, 175, 177, 178, 186, 193, 198, 206, 214, 218, 219, 226, 227, 233, 245, 249, 253, 256, 257, 258, 261, 282, 285, 288, 289, 291, 299, 300, 303, 307, 310, 311, 314, 317, 324, 325, 328, 333, 334, 345, 347, 349, 355, 357, 363, 368, 369, 371, 380, 389, 392, 396, 397, 411, 415, 421, 423, 425, 429, 430, 433, 437, 438, ...]}

# %%
#get_group
positions.get_group('SG')['Salary'].sum()
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#max(), min(), sum(), mean()
positions['Age'].mean()
positions['Weight'].mean()
positions['Age'].min()
positions['Salary'].sum()
positions['Salary'].min()
positions['Salary'].max()
# Out:
# Position
# C     22359364.0
# PF    22192730.0
# PG    21468695.0
# SF    25000000.0
# SG    20000000.0
# Name: Salary, dtype: float64

# %%
positions[['Weight', 'Salary']].mean()
# Out:
#               Weight        Salary
# Position
# C         254.205128  5.967052e+06
# PF        240.430000  4.562483e+06
# PG        189.478261  5.077829e+06
# SF        221.776471  4.857393e+06
# SG        206.686275  4.009861e+06

# %% [markdown]
# ## Grouping by Multiple Columns

# %%
nba = pd.read_csv("Data/nba.csv",
                  dtype={'Number': 'int', 'Age':'int'},
                  usecols=lambda title: 'Height' not in title,
                 )
positions_and_age = nba.groupby(['Position', 'Age'])
positions_and_age.get_group(('PG', 20))
# Out:
#                  Name                    Team  Number Position  Age  Weight  \
# 116  D'Angelo Russell      Los Angeles Lakers       1       PG   20   195.0
# 393   Emmanuel Mudiay          Denver Nuggets       0       PG   20   200.0
# 401        Tyus Jones  Minnesota Timberwolves       1       PG   20   195.0
# 445        Dante Exum               Utah Jazz      11       PG   20   190.0
#
#         College     Salary
# 116  Ohio State  5103120.0
# 393         NaN  3102240.0
# 401        Duke  1282080.0
# 445         NaN  3777720.0

# %%
positions_and_age.sum()
positions_and_age['Salary'].mean()
positions_and_age['Salary'].max()
# Out:
# Position  Age
# C         20      5703600.0
#           21      1842000.0
#           22      4626960.0
#           23      4204200.0
#           24     16407500.0
#                     ...
# SG        34     20000000.0
#           35      5746479.0
#           36      5675000.0
#           38      2814000.0
#           39      4088019.0
# Name: Salary, Length: 94, dtype: float64

# %% [markdown]
# ## Iterating through Groups

# %%
nba = pd.read_csv("Data/nba.csv")
positions = nba.groupby('Position')

# %%
nba_highest_salaries = pd.DataFrame(columns = nba.columns)
nba_highest_salaries
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Weight, College, Salary]
# Index: []

# %%
for position, data in positions:
    highest_salary_in_nba = data.nlargest(1, 'Salary')
    nba_highest_salaries = nba_highest_salaries.append(highest_salary_in_nba)
nba_highest_salaries
# Out:
#               Name                  Team  Number Position   Age  Weight  \
# 251  Dwight Howard       Houston Rockets    12.0        C  30.0   265.0
# 339     Chris Bosh            Miami Heat     1.0       PF  32.0   235.0
# 100     Chris Paul  Los Angeles Clippers     3.0       PG  31.0   175.0
# 109    Kobe Bryant    Los Angeles Lakers    24.0       SF  37.0   212.0
# 349    Dwyane Wade            Miami Heat     3.0       SG  34.0   220.0
#
#           College      Salary Height
# 251           NaN  22359364.0   6-11
# 339  Georgia Tech  22192730.0   6-11
# 100   Wake Forest  21468695.0    6-0
# 109           NaN  25000000.0    6-6
# 349     Marquette  20000000.0    6-4

# %%
nba.groupby('Salary').filter(lambda x: x['Salary'].count() > 12)
# Out:
#                  Name                    Team  Number Position  Age  Weight  \
# 16       Markel Brown           Brooklyn Nets      22       SG   24   190.0
# 25        Willie Reed           Brooklyn Nets      33       PF   26   220.0
# 27         Henry Sims           Brooklyn Nets      14        C   26   248.0
# 28       Donald Sloan           Brooklyn Nets      15       PG   28   205.0
# 35   Cleanthony Early         New York Knicks      11       SF   25   210.0
# ..                ...                     ...     ...      ...  ...     ...
# 406   Tayshaun Prince  Minnesota Timberwolves      12       SF   36   212.0
# 427   Cliff Alexander  Portland Trail Blazers      34       PF   20   240.0
# 430      Allen Crabbe  Portland Trail Blazers      23       SG   24   210.0
# 438      Luis Montero  Portland Trail Blazers      44       SG   23   185.0
# 456       Jeff Withey               Utah Jazz      24        C   26   231.0
#
#             College    Salary
# 16   Oklahoma State  845059.0
# 25      Saint Louis  947276.0
# 27       Georgetown  947276.0
# 28        Texas A&M  947276.0
# 35    Wichita State  845059.0
# ..              ...       ...
# 406        Kentucky  947276.0
# 427          Kansas  525093.0
# 430      California  947276.0
# 438  Westchester CC  525093.0
# 456          Kansas  947276.0
#
# [62 rows x 8 columns]

# %%
nba.groupby('Salary').filter(lambda x: x['Salary'].count() > 12)['Salary'].unique()
# Out:
# array([845059., 947276., 525093.])

# %%
nba['Total Salary Per Position in a league'] = positions['Salary'].transform('sum')
nba.head()
# Out:
#             Name            Team  Number Position  Age  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25   235.0
# 2   John Holland  Boston Celtics      30       SG   27   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   231.0
#
#              College     Salary  Total Salary Per Position in a league
# 0              Texas  7730337.0                            446848971.0
# 1          Marquette  6796117.0                            408020976.0
# 2  Boston University        NaN                            396976258.0
# 3      Georgia State  1148640.0                            396976258.0
# 4                NaN  5000000.0                            442560850.0

# %%
nba['Percentage Salary of a Player per position in a league'] = positions['Salary'].fillna(0).transform(lambda x: x/x.sum() * 100)
nba.head()
# Out:
#             Name            Team  Number Position  Age  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25   235.0
# 2   John Holland  Boston Celtics      30       SG   27   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   231.0
#
#              College     Salary  Total Salary Per Position in a league  \
# 0              Texas  7730337.0                            446848971.0
# 1          Marquette  6796117.0                            408020976.0
# 2  Boston University        NaN                            396976258.0
# 3      Georgia State  1148640.0                            396976258.0
# 4                NaN  5000000.0                            442560850.0
#
#    Percentage Salary of a Player per position in a league
# 0                                           0.357913
# 1                                           0.314659
# 2                                           0.000000
# 3                                           0.053182
# 4                                           0.231499

# %%
nba = pd.read_csv("Data/nba.csv")
teams = nba.groupby('Team')
nba_team = pd.DataFrame(columns = nba.columns)
nba_team
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
for team, data in teams:
    higest_salary_in_a_team = data.nlargest(1, 'Salary')
    nba_team = nba_team.append(higest_salary_in_a_team)
nba_team.head()
# Out:
#              Name               Team  Number Position   Age Height  Weight  \
# 315  Paul Millsap      Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# 5    Amir Johnson     Boston Celtics    90.0       PF  29.0    6-9   240.0
# 23    Brook Lopez      Brooklyn Nets    11.0        C  28.0    7-0   275.0
# 330  Al Jefferson  Charlotte Hornets    25.0        C  31.0   6-10   289.0
# 164  Derrick Rose      Chicago Bulls     1.0       PG  27.0    6-3   190.0
#
#             College      Salary
# 315  Louisiana Tech  18671659.0
# 5               NaN  12000000.0
# 23         Stanford  19689000.0
# 330             NaN  13500000.0
# 164         Memphis  20093064.0

# %% [markdown]
# ## The `.agg()` Method

# %%
teams['Salary'].sum()
teams['Salary'].mean()
# Out:
# Team
# Atlanta Hawks             4.860197e+06
# Boston Celtics            4.181505e+06
# Brooklyn Nets             3.501898e+06
# Charlotte Hornets         5.222728e+06
# Chicago Bulls             5.785559e+06
# Cleveland Cavaliers       7.642049e+06
# Dallas Mavericks          4.746582e+06
# Denver Nuggets            4.294424e+06
# Detroit Pistons           4.477884e+06
# Golden State Warriors     5.924600e+06
# Houston Rockets           5.018868e+06
# Indiana Pacers            4.450122e+06
# Los Angeles Clippers      6.323643e+06
# Los Angeles Lakers        4.784695e+06
# Memphis Grizzlies         5.467920e+06
# Miami Heat                6.347359e+06
# Milwaukee Bucks           4.350220e+06
# Minnesota Timberwolves    4.593054e+06
# New Orleans Pelicans      4.355304e+06
# New York Knicks           4.581494e+06
# Oklahoma City Thunder     6.251020e+06
# Orlando Magic             4.297248e+06
# Philadelphia 76ers        2.213778e+06
# Phoenix Suns              4.229676e+06
# Portland Trail Blazers    3.220121e+06
# Sacramento Kings          4.778911e+06
# San Antonio Spurs         5.629516e+06
# Toronto Raptors           4.741174e+06
# Utah Jazz                 4.204006e+06
# Washington Wizards        5.088576e+06
# Name: Salary, dtype: float64

# %%
teams.agg({'Salary': ['sum', 'mean'],
           'Age': 'mean'
          })
# Out:
#                              Salary                      Age
#                                 sum          mean       mean
# Team
# Atlanta Hawks            72902950.0  4.860197e+06  28.200000
# Boston Celtics           58541068.0  4.181505e+06  24.733333
# Brooklyn Nets            52528475.0  3.501898e+06  25.600000
# Charlotte Hornets        78340920.0  5.222728e+06  26.133333
# Chicago Bulls            86783378.0  5.785559e+06  27.400000
# Cleveland Cavaliers     106988689.0  7.642049e+06  29.533333
# Dallas Mavericks         71198732.0  4.746582e+06  29.733333
# Denver Nuggets           60121930.0  4.294424e+06  25.733333
# Detroit Pistons          67168263.0  4.477884e+06  26.200000
# Golden State Warriors    88868997.0  5.924600e+06  27.666667
# Houston Rockets          75283021.0  5.018868e+06  26.866667
# Indiana Pacers           66751826.0  4.450122e+06  26.400000
# Los Angeles Clippers     94854640.0  6.323643e+06  29.466667
# Los Angeles Lakers       71770431.0  4.784695e+06  27.533333
# Memphis Grizzlies        76550880.0  5.467920e+06  28.388889
# Miami Heat               82515673.0  6.347359e+06  28.933333
# Milwaukee Bucks          69603517.0  4.350220e+06  24.562500
# Minnesota Timberwolves   59709697.0  4.593054e+06  26.357143
# New Orleans Pelicans     82750774.0  4.355304e+06  26.894737
# New York Knicks          73303898.0  4.581494e+06  27.000000
# Oklahoma City Thunder    93765298.0  6.251020e+06  27.066667
# Orlando Magic            60161470.0  4.297248e+06  25.071429
# Philadelphia 76ers       30992894.0  2.213778e+06  24.600000
# Phoenix Suns             63445135.0  4.229676e+06  25.866667
# Portland Trail Blazers   48301818.0  3.220121e+06  25.066667
# Sacramento Kings         71683666.0  4.778911e+06  26.800000
# San Antonio Spurs        84442733.0  5.629516e+06  31.600000
# Toronto Raptors          71117611.0  4.741174e+06  26.133333
# Utah Jazz                63060091.0  4.204006e+06  24.466667
# Washington Wizards       76328636.0  5.088576e+06  27.866667

# %%
teams.agg(['size', 'sum', 'mean'])
# Out:
#                        Number                    Age                   Weight  \
#                          size    sum       mean size    sum       mean   size
# Team
# Atlanta Hawks              15  285.0  19.000000   15  423.0  28.200000     15
# Boston Celtics             15  478.0  31.866667   15  371.0  24.733333     15
# Brooklyn Nets              15  274.0  18.266667   15  384.0  25.600000     15
# Charlotte Hornets          15  257.0  17.133333   15  392.0  26.133333     15
# Chicago Bulls              15  288.0  19.200000   15  411.0  27.400000     15
# Cleveland Cavaliers        15  217.0  14.466667   15  443.0  29.533333     15
# Dallas Mavericks           15  300.0  20.000000   15  446.0  29.733333     15
# Denver Nuggets             15  229.0  15.266667   15  386.0  25.733333     15
# Detroit Pistons            15  259.0  17.266667   15  393.0  26.200000     15
# Golden State Warriors      15  313.0  20.866667   15  415.0  27.666667     15
# Houston Rockets            15  220.0  14.666667   15  403.0  26.866667     15
# Indiana Pacers             15  284.0  18.933333   15  396.0  26.400000     15
# Los Angeles Clippers       15  293.0  19.533333   15  442.0  29.466667     15
# Los Angeles Lakers         15  241.0  16.066667   15  413.0  27.533333     15
# Memphis Grizzlies          18  280.0  15.555556   18  511.0  28.388889     18
# Miami Heat                 15  157.0  10.466667   15  434.0  28.933333     15
# Milwaukee Bucks            16  320.0  20.000000   16  393.0  24.562500     16
# Minnesota Timberwolves     14  274.0  19.571429   14  369.0  26.357143     14
# New Orleans Pelicans       19  323.0  17.000000   19  511.0  26.894737     19
# New York Knicks            16  212.0  13.250000   16  432.0  27.000000     16
# Oklahoma City Thunder      15  210.0  14.000000   15  406.0  27.066667     15
# Orlando Magic              14  230.0  16.428571   14  351.0  25.071429     14
# Philadelphia 76ers         15  271.0  18.066667   15  369.0  24.600000     15
# Phoenix Suns               15  232.0  15.466667   15  388.0  25.866667     15
# Portland Trail Blazers     15  240.0  16.000000   15  376.0  25.066667     15
# Sacramento Kings           15  254.0  16.933333   15  402.0  26.800000     15
# San Antonio Spurs          15  269.0  17.933333   15  474.0  31.600000     15
# Toronto Raptors            15  337.0  22.466667   15  392.0  26.133333     15
# Utah Jazz                  15  268.0  17.866667   15  367.0  24.466667     15
# Washington Wizards         15  264.0  17.600000   15  418.0  27.866667     15
#
#                                            Salary
#                            sum        mean   size          sum          mean
# Team
# Atlanta Hawks           3319.0  221.266667     15   72902950.0  4.860197e+06
# Boston Celtics          3292.0  219.466667     15   58541068.0  4.181505e+06
# Brooklyn Nets           3234.0  215.600000     15   52528475.0  3.501898e+06
# Charlotte Hornets       3306.0  220.400000     15   78340920.0  5.222728e+06
# Chicago Bulls           3284.0  218.933333     15   86783378.0  5.785559e+06
# Cleveland Cavaliers     3418.0  227.866667     15  106988689.0  7.642049e+06
# Dallas Mavericks        3405.0  227.000000     15   71198732.0  4.746582e+06
# Denver Nuggets          3263.0  217.533333     15   60121930.0  4.294424e+06
# Detroit Pistons         3333.0  222.200000     15   67168263.0  4.477884e+06
# Golden State Warriors   3369.0  224.600000     15   88868997.0  5.924600e+06
# Houston Rockets         3305.0  220.333333     15   75283021.0  5.018868e+06
# Indiana Pacers          3334.0  222.266667     15   66751826.0  4.450122e+06
# Los Angeles Clippers    3296.0  219.733333     15   94854640.0  6.323643e+06
# Los Angeles Lakers      3406.0  227.066667     15   71770431.0  4.784695e+06
# Memphis Grizzlies       3924.0  218.000000     18   76550880.0  5.467920e+06
# Miami Heat              3276.0  218.400000     15   82515673.0  6.347359e+06
# Milwaukee Bucks         3585.0  224.062500     16   69603517.0  4.350220e+06
# Minnesota Timberwolves  3201.0  228.642857     14   59709697.0  4.593054e+06
# New Orleans Pelicans    4199.0  221.000000     19   82750774.0  4.355304e+06
# New York Knicks         3578.0  223.625000     16   73303898.0  4.581494e+06
# Oklahoma City Thunder   3441.0  229.400000     15   93765298.0  6.251020e+06
# Orlando Magic           2987.0  213.357143     14   60161470.0  4.297248e+06
# Philadelphia 76ers      3332.0  222.133333     15   30992894.0  2.213778e+06
# Phoenix Suns            3279.0  218.600000     15   63445135.0  4.229676e+06
# Portland Trail Blazers  3279.0  218.600000     15   48301818.0  3.220121e+06
# Sacramento Kings        3320.0  221.333333     15   71683666.0  4.778911e+06
# San Antonio Spurs       3359.0  223.933333     15   84442733.0  5.629516e+06
# Toronto Raptors         3327.0  221.800000     15   71117611.0  4.741174e+06
# Utah Jazz               3300.0  220.000000     15   63060091.0  4.204006e+06
# Washington Wizards      3285.0  219.000000     15   76328636.0  5.088576e+06

# %% [markdown]
# ## Quick look at the Visualisations

# %%
# Creating a Series plot
ts = pd.Series(np.random.rand(1000), index=pd.date_range('1/1/2020', periods=1000))
ts = ts.cumsum() #cumulative sum
ts.plot();

# %%
# Creating a DF bar plot
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.bar();

# %%
# Creating a DF histogram plot
df2  = pd.DataFrame(
    {
        'a': np.random.rand(1000) + 1,
        'b': np.random.rand(1000),
        'c': np.random.rand(1000) - 1,
    },
    columns=['a', 'b', 'c'],
)
df2.plot.hist(alpha=0.5);

# %%
# Creating a DF scatter plot
df3 = pd.DataFrame(np.random.rand(50, 2), columns=['a', 'b'])
df3.plot.scatter(x='a', y='b');

# %%
# Creating a DF area plot
df4 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df4.plot.area();

# %%
# Creating a Series pie plot
series_pie_plot = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series_pie_plot')
series_pie_plot.plot.pie(figsize=(6,6));

# %% [markdown]
# # <b> END OF LECTURE 1 SESSION 2 ON PANDAS</b>

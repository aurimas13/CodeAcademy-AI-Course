# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# # Jeigu dirbate data analysis srity jums gali tekti daznai naudoti sujungimus ir mes dabar isiaiskinsime kuri metoda geriau naudoti: pd.merge() ar pd.concat().

# %% [markdown]
# ## Do you want to concatenate data?
# ![Screenshot 2022-11-19 at 09.27.37.png](attachment:8b24116f-e4dd-4b45-9f77-5c7ec48a16de.png)
# ## Or do you want to use database join operations?
# ![Screenshot 2022-11-19 at 09.30.55.png](attachment:5f7cc38c-837e-4922-8514-e14ba416b008.png)
# # Ir ka visa tai reiskia?
# ![Screenshot 2022-11-19 at 09.32.54.png](attachment:edd7cfbe-4090-47a9-b844-6f4c9be6df59.png)

# %% [markdown]
# # Pradzioje mes sukursime mazus data set'us kurie sudaryti is darzoviu ir vaisiu:

# %%
couple_of_fruits = 

vegetables =
